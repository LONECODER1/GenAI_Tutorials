# %%
fruits=["Apple","Banana","cherry","kiwi"]
print(fruits)
# Out:
# ['Apple', 'Banana', 'cherry', 'kiwi']

# %%
fruits.append("orange")
print(fruits)
# Out:
# ['Apple', 'Banana', 'cherry', 'kiwi', 'orange', 'orange']

# %%
fruits.insert(1,"lemon")
print(fruits)
# Out:
# ['Apple', 'lemon', 'Banana', 'cherry', 'kiwi', 'orange', 'orange']

# %%
fruits.remove('Banana')##Removing the first occurance of an item
print(fruits)
# Out:
# ['Apple', 'lemon', 'cherry', 'kiwi', 'orange', 'orange']

# %%
fruits.pop()
print(fruits)
# Out:
# ['Apple', 'lemon', 'cherry', 'kiwi', 'orange']

# %%
print(fruits.index("cherry"))
# Out:
# 2

# %%
fruits.insert(2,'banana')
print(fruits.count('banana'))
# Out:
# 1

# %%
fruits.sort()#Sorts the list in asc order
print(fruits)
# Out:
# ['Apple', 'banana', 'cherry', 'kiwi', 'lemon', 'orange']

# %%
fruits.reverse()
fruits
# Out:
# ['orange', 'lemon', 'kiwi', 'cherry', 'banana', 'Apple']
