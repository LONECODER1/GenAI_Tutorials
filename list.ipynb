# %%
print("Hello World")
# Out:
# Hello World

# %%
lst = []
print(type(lst))
# Out:
# <class 'list'>

# %%
names =["Aditya","Jack","Jacob",1,2,2,3]

# %%
print(names)
# Out:
# ['Aditya', 'Jack', 'Jacob', 1, 2, 2, 3]

# %%
print(names[0])
# Out:
# Aditya

# %%
print(names[-1])#last item
# Out:
# 3

# %%
print(names[1:])#upto the last element
print(names[1:4])#1 step before the last element
# Out:
# ['Jack', 'Jacob', 1, 2, 2, 3]
# ['Jack', 'Jacob', 1]
