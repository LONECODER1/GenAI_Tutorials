# %%
# Tuples => Tuples are ordered collections of items that are immutable. They are similar to lists,but their immutability makes them different.


## creating a tuple

empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))

lst=list()
print(type(lst))

# %%
mixed_tuple=(1,"Hello World",3.14,True)
print(mixed_tuple)

# %%
print(mixed_tuple[1])
print(mixed_tuple[-1])
print(mixed_tuple[1:4])
print(mixed_tuple[::-1])

# %%
## Tuple Operations
numbers=(1,2,3,4,5,6)
concatenation_tuple=numbers+mixed_tuple
print(concatenation_tuple)
print(mixed_tuple*3)

# %%
## Immuttable Nature of Tuples
## tuples are immutable, meaning their elemnts cannot be changed once assigned

lst = (1,2,3,4,5)
print(lst)

lst[1]="Krish"
print(lst)
# Out:
# (1, 2, 3, 4, 5)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       3
#       4 lst = (1,2,3,4,5)
#       5 print(lst)
#       6
# ----> 7 lst[1]="Krish"
#       8 print(lst)
#
# TypeError: 'tuple' object does not support item assignment
